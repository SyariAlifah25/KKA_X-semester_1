# %% [markdown]
# <a href="https://colab.research.google.com/github/SyariAlifah25/KKA_X-semester_1/blob/main/2_Tipe_Variabel_Syarifatul_A_X_11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Syarifatul A
#
#
# Kelas:X.11
#
#
# No.absen:34

# %%
print("shintahanafiaa.2025@gmail.com")
print("shintahanafiaa.2025@gmail.com")
print("shintahanafiaa.2025@gmail.com")
# Out:
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com
# shintahanafiaa.2025@gmail.com

# %%
email_user_1= "shintahanafia.2025@gmail.com"

print(email_user_1)
print(email_user_1)
print (email_user_1)
# Out:
# shintahanafia.2025@gmail.com
# shintahanafia.2025@gmail.com
# shintahanafia.2025@gmail.com

# %%
#Hanya diperbolehkan menggunakan huruf,angka,dan underscore

email user 2="bobbyaliando@gmail.com"


print (email user 2)
# Out:
#   File "/tmp/ipython-input-2510828800.py", line 3
#     email user 2="bobbyaliando@gmail.com"
#           ^
# SyntaxError: invalid syntax

# %%
emailuser2 ="bobbyaliando@gmail.com"

print (emailuser2)
# Out:
# bobbyaliando@gmail.com

# %%
#Tidak boleh didahului oleh angka
3_email_user = "willytaulany@gmail.com"
# Out:
#   File "/tmp/ipython-input-1936439504.py", line 2
#     3_email_user = "willytaulany@gmail.com"
#      ^
# SyntaxError: invalid decimal literal

# %%
email_user_3 ="willytaulany@gmail.com"

print(email_user_3)
# Out:
# willytaulany@gmail.com

# %%
#Tidak boleh menggunakan kata kunci python
for="HimamHimawan@Gmail.com"

print(for)
# Out:
#   File "/tmp/ipython-input-3110034514.py", line 2
#     for="HimamHimawan@Gmail.com"
#        ^
# SyntaxError: invalid syntax

# %%
For = "HimamHimawan@Gmail.com"

print (For)
# Out:
# HimamHimawan@Gmail.com

# %%
print ="Juliawati@gmail.com"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2654162610.py in <cell line: 0>()
#       1 print ="Juliawati@gmail.com"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print="Juliawati@gmail.com"

print(Print)
# Out:
# Juliawati@gmail.com

# %%
#tidak eror tapi dianjurkan harus deskriptif
_="Devandraarnoldi@gmail.com"

# %%
print(_)
# Out:
# Devandraarnoldi@gmail.com

# %%
_="haidarhalilintar@Gmail.com"

# %%
print(_)
# Out:
# haidarhalilintar@Gmail.com

# %% [markdown]
# #Assigment

# %%
single assigment
nama_mahasiswa_1="alexandrio"

print(nama_mahasiswa_1)
# Out:
#   File "/tmp/ipython-input-1925626536.py", line 1
#     single assigment
#            ^
# SyntaxError: invalid syntax

# %%
#multi Assigment

# nama_barang_1 ="rinso"
# nama_barang_2 ="molto"

nama_barang_1,nama_barang_2= "rinso","molto"

print (nama_barang_1)
print (nama_barang_2)
# Out:
# rinso
# molto

# %%
#Assigment yang sama

nilai_devandra =nilai_willy =nilai_dzaki =100

print(nilai_devandra)
print (nilai_willy)
print(nilai_dzaki)
# Out:
# 100
# 100
# 100

# %%
#menimpa/mengubah nilai variabel

nilai_himam =95

# %%
print (nilai_himam)
# Out:
# 95

# %%
nilai_himam= 100

# %%
print (nilai_himam)
# Out:
# 100

# %% [markdown]
# #pengunaan operator di python

# %%
#tanpa variabel

print (20+3)
# Out:
# 23

# %%
#operand disimpan ke dalam variabel
roti_swiss_alex = 20
roti_swiss_nazril=3

print (roti_swiss_alex+roti_swiss_nazril)
# Out:
# 23

# %%
#hasil operasi disimpan kedalam variabel

jumlah_roti_swiss=20+3

print (jumlah_roti_swiss)
# Out:
# 23

# %%
#operand dan hasil operasi disimpan ke variabel

roti_swiss_alex=20
roti_swiss_nazril=3

jumlah_roti_swiss=roti_swiss_alex+roti_swiss_nazril

print(jumlah_roti_swiss)
# Out:
# 23

# %%
print (3*24)
# Out:
# 72

# %%
total_jumlah_botol =72

print (total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus=24
jumlah_kardus=3

print (banyak_botol_per_kardus*jumlah_kardus)
# Out:
# 72

# %%
banyak_botol_per_kardus=24
jumlah_kardus=3

print (total_jumlah_botol)
# Out:
# 72

# %% [markdown]
# #operator aritmatika

# %%
buku_tulis_himam =55
buku_tulis_vico =15

# %%
#penjumlahan
total_buku_tulis=buku_tulis_himam+buku_tulis_vico

print (total_buku_tulis)
# Out:
# 70

# %%
#pengurangan
selisi_buku_tulis= buku_tulis_himam-buku_tulis_vico

print (selisi_buku_tulis)
# Out:
# 40

# %%
#perkalian
jumlah_kardus_buku_tulis = 3
isi_buku_tulis_perkardus = 10

total_buku_tulis =jumlah_kardus_buku_tulis * isi_buku_tulis_perkardus
print(total_buku_tulis)
# Out:
# 30

# %%
#pembagian
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak= total_buku_tulis /jumlah_anak_yatim
print (jumlah_buku_tulis_tiap_anak)
# Out:
# 3.3333333333333335

# %%
#Pembagian bulat
jumlah_anak_yatim = 9

jumlah_buku_tulis_tiap_anak = total_buku_tulis // jumlah_anak_yatim
print(jumlah_buku_tulis_tiap_anak)
# Out:
# 3

# %%
#Sisa bagi

sisa_buku_tulis = total_buku_tulis % jumlah_anak_yatim
print(sisa_buku_tulis)
# Out:
# 3

# %%
#perpangkatan
sisi = 5
luas_persegi = sisi ** 2

print (luas_persegi)
# Out:
# 25

# %%
luas_persegi = 36

sisi = luas_persegi ** (1/2)
print(sisi)
# Out:
# 6.0

# %% [markdown]
# #Tipe Variabel

# %%
usia = 8

print(usia)
type(usia)
# Out:
# 8
# int

# %%
berat_badan = 72.5

type(berat_badan)
# Out:
# float

# %%
nama = "dzaki"

type(nama)
# Out:
# str

# %%
lulus = True

type (lulus)
# Out:
# bool

# %%
titik_koordinat =-5

type(titik_koordinat)
# Out:
# int

# %%
titik_koordinat_bintang =10.0

type (titik_koordinat_bintang)
# Out:
# float

# %% [markdown]
# #Konversi Tipe Data

# %%
usia = 7

print(usia)
type(usia)
# Out:
# 7
# int

# %%
usia = float(usia)

print(usia)
type (usia)
# Out:
# 7.0
# float

# %%
berat_badan = 72.5

print(berat_badan)
type (berat_badan)
# Out:
# 72.5
# float

# %%
berat_badan = int(berat_badan)
print (berat_badan)
type (berat_badan)
# Out:
# 72
# int

# %%
usia = 7
print (usia)
type (usia)
# Out:
# 7
# int

# %%
usia =str(usia)
print(usia)
type(usia)
# Out:
# 7
# str

# %%
lulus = 1
print(lulus)
type(lulus)
# Out:
# 1
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# True
# bool

# %%
lulus = 0
print(lulus)
type(lulus)
# Out:
# 0
# int

# %%
lulus = bool(lulus)
print(lulus)
type(lulus)
# Out:
# False
# bool

# %% [markdown]
# #Operator perbandingan

# %%
print (6 >= 6)
# Out:
# True

# %%
print (8 == 9)
# Out:
# False

# %%
print (8 != 9)
# Out:
# True

# %%
print (8 < 10)
# Out:
# True

# %%
print (8 > 10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print (not(5 <= 5))
# Out:
# False

# %%
print (8 > 7 and 6 <5)
# Out:
# False

# %%
print (7 <= 1 or 2 != 2)
# Out:
# False

# %%
print (not( 0 == 1 and 1 != 1))
# Out:
# True

# %%
print (not(5 < 10 or 5 <= 10))
# Out:
# False
