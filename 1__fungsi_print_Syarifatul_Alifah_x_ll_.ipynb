# %% [markdown]
# <a href="https://colab.research.google.com/github/SyariAlifah25/KKA_X-semester_1/blob/main/1__fungsi_print_Syarifatul_Alifah_x_ll_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Nama: Syarifatul Alifah
#
# Kelas:X.11
#
# No Absen:34

# %% [markdown]
# #Menampilkan Teks Bebas

# %%
print("Syarifatul Alifah")
# Out:
# Syarifatul Alifah

# %%
print ("atta halilintar")
# Out:
# atta halilintar

# %% [markdown]
# #Menampilkan nilai variabel

# %%
nama_saudara="ayu dia inara"
print(nama_saudara )
# Out:
# ayu dia inara

# %%
jumlah_saudara=3
print(jumlah_saudara)
# Out:
# 3

# %%
nama_idola ="atta halilintar"

print (nama_idola)
print ("nama_idola")
# Out:
# atta halilintar
# nama_idola

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan Tanda Koma

# %%
print ("Saya memiliki saudara sebanyak", jumlah_saudara,"Nama saudara saya adalah",nama_saudara)
# Out:
# Saya memiliki saudara sebanyak 3 Nama saudara saya adalah ayu dia inara

# %% [markdown]
# #Menampilkan Teks Bebas dan Nilai Variabel Menggunakan Tanda Plus

# %%
print ("Saya memiliki saudara sebanyak"+ str(jumlah_saudara) + "."+ "Nama saudara saya adalah "  +  nama_saudara + ".")
# Out:
# Saya memiliki saudara sebanyak3.Nama saudara saya adalah ayu dia inara.

# %% [markdown]
# ##Menampilkan Teks Bebas dan Nilai Variabel Menggunakan f String

# %%
print(f"saya memiliki saudara sebanyak {jumlah_saudara}.Nama saudara saya adalah {nama_saudara}.")
# Out:
# saya memiliki saudara sebanyak 3.Nama saudara saya adalah ayu dia inara.

# %%
print (nama_siswa_1,end="-")
print (nama_siswa_2)
# Out:
# Daffanes-Adzka

# %% [markdown]
# #Escape Character

# %%
print("Nama: Syarifatul Alifah")
print ("kelas: X.11")
print("No.Absen: 34")
# Out:
# Nama: Syarifatul Alifah
# kelas: X.11
# No.Absen: 34

# %%
print("Nama: Syarifatul Alifah \nkelas: X.11\nNo. Absen:29")
# Out:
# Nama: Syarifatul Alifah
# kelas: X.11
# No. Absen:29

# %%
print("Syarifatul Alifah")
# Out:
# Syarifatul Alifah

# %%
print ('Syarifatul Alifah')
# Out:
# Syarifatul Alifah

# %%
print ('Atta Hali\'lintar')
# Out:
# Atta Hali'lintar

# %%
print("Atta halilintar")
# Out:
# Atta halilintar

# %%
print('Bu Sinta berkata,"Harap fokus menyimak!".')
# Out:
# Bu Sinta berkata,"Harap fokus menyimak!".

# %%
print ("Bu Sinta berkata,\"Harap fokus menyimak!\".")
# Out:
# Bu Sinta berkata,"Harap fokus menyimak!".

# %%
print ("Lokasi penyimpanan tugas KKA di D:\\MAN Demak \\KKA\\Tugas")
# Out:
# Lokasi penyimpanan tugas KKA di D:\MAN Demak \KKA\Tugas

# %% [markdown]
# #Fungsi Paramater

# %%
nama_siswa_1 = "Daffanes"
nama_siswa_2 = "Adzka"
nama_siswa_3 = "Haidar"

print(nama_siswa_3,nama_siswa_2,nama_siswa_1,nama_siswa_2,sep="_")
# Out:
# Haidar_Adzka_Daffanes_Adzka

# %%
print(nama_siswa_1)
print (nama_siswa_2)
# Out:
# Daffanes
# Adzka

# %%
print (nama_siswa_1,nama_siswa_2)
# Out:
# Daffanes Adzka

# %%
print(nama_siswa_1,end="_")
print (nama_siswa_2)
# Out:
# Daffanes_Adzka

# %% [markdown]
# #Latihan soal:
# #Gunakan parameter end untuk menampilkan tulisan sebagai berikut:
# #Haidar#Adzka#Daffanes#Adzka
